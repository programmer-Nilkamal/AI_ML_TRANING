# %% [markdown]
# <a href="https://colab.research.google.com/github/programmer-Nilkamal/AI_ML_TRANING/blob/main/project%201/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Variable,Data type,operators

# %%
# Calculate area of a triangle
h = 20
b = 10
area = 1/2 * b * h
print(area)
# Out:
# 100.0

# %% [markdown]
# understand f-string

# %%
# Calculate area of a triangle
h = 20
b = 10
area = 1/2 * b * h
print("The area is :",1/2 * b * h)
print(f"The area is: {1/2 * b * h}")
# Out:
# The area is : 100.0
# The area is: 100.0

# %% [markdown]
# List & indexing

# %%
marks = [70, 85, 90, 60]
print(marks)
print (marks[0]) #first element
print (marks[-1]) #last element
# Out:
# [70, 85, 90, 60]
# 70
# 60

# %% [markdown]
# conditional statements(if-else,if-elif-else,nested)what is indentation

# %%
age=23
if(age>18):
  print("you can drive")
else:
    print("oops! you cannot drive")
# Out:
# you can drive

# %%
#Largest among three element
a,b,c=10,20,30
if(a>b and a>c):
  print("a is largest")
elif(b>a and b>c):
  print("b is largest")
else:
  print("c is largest")
# Out:
# c is largest

# %% [markdown]
# ** let's understand modules
#
# a python file(various function)

# %%
import math
print(math.sqrt(16))
print(math.pow(2,3))
print(math.pi)
print(max(10,20,30,40,100))
print(math.pi+max(10,20,30,40,100))
# Out:
# 4.0
# 8.0
# 3.141592653589793
# 100
# 103.1415926535898

# %%
#print current data &time
import datetime
a = datetime.datetime.now()
print(f"the current date & time is:{a}")
# Out:
# the current date & time is:2026-02-18 06:36:29.837919

# %% [markdown]
# Loop: for,while

# %%
# print 1-100 using for loop
print("using for loop")
for i in range(10,3,-1):
 print(i)
for i in range(10,3,-2):
 print(i)
 for i in range(10,3,-2):
  print(i)

  # print even number 1-10
  print("")
  for i in range(10,3,-2):
   print(i)

  # print even number 1-10
  for i in range(10,3,-2):
   print(i)

    # print odd number 1-10
    for i in range(10,3,-2):
     print(i)

    # print reverse number 1-10
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4

# %% [markdown]
# string &it's methods

# %%
name ="Ardent"


print(name)
print(name.upper())
print(name.lower())
print(name.index("A"))
# Out:
# Ardent
# ARDENT
# ardent
# 0

# %% [markdown]
# **Functions**
#
# **User Defined function :** As a deve

# %%
#function to calculate average

def avg(phy,che,math):
  return (phy+che+math)/3

print(avg(50,60,80))


#for perfection u should  know function defination, parameters, calling function ,arguments
# Out:
# 63.333333333333336
